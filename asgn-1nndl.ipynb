# %%
from sympy import *
x=Symbol('x')
dx=diff(x**4+3*x**2+10,x)
print(dx)
x0=1.0
a=150
n=0.01
for i in range(0,a):
  x=symbols('x')
  x1=x0-((n)*(dx.subs(x,x0)))
  x0=x1
print(round(x0,2))
# Out:
# 4*x**3 + 6*x
# 0.0
